# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\najibmch12\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\najibmch12\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\najibmch12\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\najibmch12\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\najibmch12\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\najibmch12\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# !pip install mplsoccer
# Out:
# Requirement already satisfied: mplsoccer in c:\users\najibmch12\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\najibmch12\anaconda3\lib\site-packages (from mplsoccer) (3.9.2)
# Requirement already satisfied: numpy in c:\users\najibmch12\anaconda3\lib\site-packages (from mplsoccer) (1.26.4)
# Requirement already satisfied: pandas in c:\users\najibmch12\anaconda3\lib\site-packages (from mplsoccer) (2.2.2)
# Requirement already satisfied: pillow in c:\users\najibmch12\anaconda3\lib\site-packages (from mplsoccer) (10.4.0)
# Requirement already satisfied: requests in c:\users\najibmch12\anaconda3\lib\site-packages (from mplsoccer) (2.32.3)
# Requirement already satisfied: scipy in c:\users\najibmch12\anaconda3\lib\site-packages (from mplsoccer) (1.13.1)
# Requirement already satisfied: seaborn in c:\users\najibmch12\anaconda3\lib\site-packages (from mplsoccer) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\najibmch12\anaconda3\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\najibmch12\anaconda3\lib\site-packages (from matplotlib>=3.6->mplsoccer) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\najibmch12\anaconda3\lib\site-packages (from matplotlib>=3.6->mplsoccer) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\najibmch12\anaconda3\lib\site-packages (from matplotlib>=3.6->mplsoccer) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\najibmch12\anaconda3\lib\site-packages (from matplotlib>=3.6->mplsoccer) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\najibmch12\anaconda3\lib\site-packages (from matplotlib>=3.6->mplsoccer) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\najibmch12\anaconda3\lib\site-packages (from matplotlib>=3.6->mplsoccer) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\najibmch12\anaconda3\lib\site-packages (from pandas->mplsoccer) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\najibmch12\anaconda3\lib\site-packages (from pandas->mplsoccer) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\najibmch12\anaconda3\lib\site-packages (from requests->mplsoccer) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\najibmch12\anaconda3\lib\site-packages (from requests->mplsoccer) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\najibmch12\anaconda3\lib\site-packages (from requests->mplsoccer) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\najibmch12\anaconda3\lib\site-packages (from requests->mplsoccer) (2024.8.30)
# Requirement already satisfied: six>=1.5 in c:\users\najibmch12\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->mplsoccer) (1.16.0)

# %%
import pandas as pd
import matplotlib.pyplot as plt 
from mplsoccer import VerticalPitch

# %%
df = pd.read_csv('erling_haaland_2022_understat.csv')

# %%
df.head()
# Out:
#        id  minute  ...  player_assisted   lastAction
# 0  479846      20  ...       Phil Foden        Cross
# 1  479847      35  ...              NaN     Standard
# 2  479854      64  ...  Kevin De Bruyne  Throughball
# 3  479855      69  ...    Jack Grealish      Chipped
# 4  479856      75  ...   Ilkay Gündogan         Pass
#
# [5 rows x 20 columns]

# %%
df['X'] = df['X'] * 100
df['Y'] = df['Y'] * 100

# %%
total_shots = df.shape[0]
total_goals = df[df['result']=='Goal'].shape[0]
total_xg = df['xG'].sum()
xg_pershot = total_xg/total_shots
points_average_distance = df['X'].mean()
actual_average_distance = 120 - (df['X']*1.2).mean()

# %%
actual_average_distance
# Out:
# 11.720000401938833

# %%
# Color -> They went with a black so we'll do the same. Notice how it isn't a pure black but rather a lighter little bit of grey black
background_color='#0C0D0E'

# %%
import matplotlib.font_manager as font_manager
font_path = 'Arvo-Regular.ttf'
# Create a font properties object with the font file
font_props = font_manager.FontProperties(fname=font_path)

# %%
pitch = VerticalPitch(
    pitch_type='opta', 
    half=True, 
    pitch_color=background_color, 
    pad_bottom=.5, 
    line_color='white',
    linewidth=.75,
    axis=True, label=True
)

# %%
fig = plt.figure(figsize=(8,12))
fig.patch.set_facecolor(background_color)
ax1 = fig.add_axes([0,0.7,1,.2])
ax1.set_facecolor(background_color)
ax1.set_xlim(0, 1)
ax1.set_ylim(0, 1)

ax1.text(
    x=0.5, 
    y=.85, 
    s='Erling Haaland', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='center'
)

ax1.text(
    x=0.5, 
    y=.75, 
    s='All shots in premier league', 
    fontsize=14, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='center'
)

ax1.text(
    x=0.25, 
    y=.5, 
    s='Low quality  chance', 
    fontsize=12, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='center'
)
ax1.scatter(
    x=0.47, 
    y=0.3, 
    s=100, 
    color='red', 
    edgecolor='white', 
    linewidth=.8,
    alpha=.7
)
# add a scatter point between the two texts
ax1.scatter(
    x=0.37, 
    y=0.53, 
    s=100, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)
ax1.scatter(
    x=0.42, 
    y=0.53, 
    s=200, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)
ax1.scatter(
    x=0.48, 
    y=0.53, 
    s=300, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)
ax1.scatter(
    x=0.54, 
    y=0.53, 
    s=400, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)
ax1.scatter(
    x=0.6, 
    y=0.53, 
    s=500, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)



ax1.scatter(
    x=0.53, 
    y=0.3, 
    s=100, 
    color=background_color, 
    edgecolor='white', 
    linewidth=.8
)

ax1.text(
    x=0.75, 
    y=.5, 
    s='High quality chance', 
    fontsize=12, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='center'
)
ax1.text(
    x=0.55, 
    y=0.27, 
    s=f'No Goal', 
    fontsize=10, 
    fontproperties=font_props, 
    color='white', 
    ha='left'
)

ax1.text(
    x=0.41,
    y=0.27, 
    s=f'Goal', 
    fontsize=10, 
    fontproperties=font_props, 
    color='white', 
    ha='left'
)

ax1.set_axis_off()


ax2 = fig.add_axes([.05,.25,.9,.5])
ax2.set_facecolor(background_color)

pitch.draw(ax=ax2)

ax2.scatter(x=90,y=points_average_distance,s=100,color='white',linewidth=.8)
ax2.plot([90,90],[100,points_average_distance],color='white',linewidth=2)

ax2.text(
    x=90,y=points_average_distance-4,
    s=f'Average Distance\n{actual_average_distance:.1f} yards',
    fontsize=10 , fontproperties=font_props,
    color='white',ha='center'
)

for x in df.to_dict(orient='records'):
    pitch.scatter ( 
        x['X'],
        x['Y'],
        s=300*x['xG'],
        color='red' if x['result']=='Goal' else background_color,
        ax = ax2 , 
        alpha = .7,
        linewidth = .8,
        edgecolor = 'white'
    )
# add another axis for the stats
ax3 = fig.add_axes([0, .2, 1, .05])
ax3.set_facecolor(background_color)
ax3.set_xlim(0, 1)
ax3.set_ylim(0, 1)

ax3.text(
    x=0.25, 
    y=.5, 
    s='Shots', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='left'
)

ax3.text(
    x=0.25, 
    y=0, 
    s=f'{total_shots}', 
    fontsize=16, 
    fontproperties=font_props, 
    color='red', 
    ha='left'
)

ax3.text(
    x=0.38, 
    y=.5, 
    s='Goals', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='left'
)
ax3.text(
    x=0.38, 
    y=0, 
    s=f'{total_goals}', 
    fontsize=16, 
    fontproperties=font_props, 
    color='red', 
    ha='left'
)
ax3.text(
    x=0.53, 
    y=.5, 
    s='xG', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='left'
)

ax3.text(
    x=0.53, 
    y=0, 
    s=f'{total_xg:.2f}', 
    fontsize=16, 
    fontproperties=font_props, 
    color='red', 
    ha='left'
)

ax3.text(
    x=0.63, 
    y=.5, 
    s='xG/Shot', 
    fontsize=20, 
    fontproperties=font_props, 
    fontweight='bold', 
    color='white', 
    ha='left'
)

ax3.text(
    x=0.63, 
    y=0, 
    s=f'{xg_pershot:.2f}', 
    fontsize=16, 
    fontproperties=font_props, 
    color='red', 
    ha='left'
)

ax3.set_axis_off()
